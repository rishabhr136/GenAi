# %%
import streamlit as st
from langchain.llms import OpenAI
import tiktoken
st.title('GeekBot')
# Out:
# 2024-07-19 23:57:03.405
# ...
#   command:
#
#     streamlit run C:\Users\risha\rishabh\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()

# %%
# Import prerequisite libraries
import os
os.environ['OPENAI_API_KEY'] = 'sk-None-5XShRHmW3NsQCYAGCLr8T3BlbkFJ4KRDfE1GEUr31Kg0oPb0'

# %%
from langchain.llms import OpenAI

# %%
import openai

# Setting the API key
openai.api_key = 'sk-None-5XShRHmW3NsQCYAGCLr8T3BlbkFJ4KRDfE1GEUr31Kg0oPb0'

# Perform tasks using OpenAI API
openai.Model.list() # List all OpenAI models
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[12], line 7
#       4 openai.api_key = 'sk-None-5XShRHmW3NsQCYAGCLr8T3BlbkFJ4KRDfE1GEUr31Kg0oPb0'
#       6 # Perform tasks using OpenAI API
# ----> 7 openai.Model.list() # List all OpenAI models
#
# File ~\rishabh\lib\site-packages\openai\lib\_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.Model, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# You can run `openai migrate` to automatically upgrade your codebase to use the 1.0.0 interface.
#
# Alternatively, you can pin your installation to the old version, e.g. `pip install openai==0.28`
#
# ...

# %%
import langchain.llms

# %%
from langchain.llms import GooglePalm

# %%
api_key = 'AIzaSyD4EKdGbVxYnB9Ua5GqqTxzQC-ETohzBIA'

llm = GooglePalm(google_api_key=api_key, temperature=0.2)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[15], line 3
#       1 api_key = 'AIzaSyD4EKdGbVxYnB9Ua5GqqTxzQC-ETohzBIA'
# ----> 3 llm = GooglePalm(google_api_key=api_key, temperature=0.2)
#
# File ~\rishabh\lib\site-packages\langchain_core\_api\deprecation.py:202, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     200 if not warned and type(self) is obj and not is_caller_internal():
#     201     warned = True
# --> 202     emit_warning()
#     203 return wrapped(self, *args, **kwargs)
#
# File ~\rishabh\lib\site-packages\langchain_core\_api\deprecation.py:139, in deprecated.<locals>.deprecate.<locals>.emit_warning()
#     137 def emit_warning() -> None:
#     138     """Emit the warning."""
# --> 139     warn_deprecated(
#     140         since,
#     141         message=_message,
# ...

# %%
import langchain_experimental
print("langchain_experimental module installed successfully!")
# Out:
# langchain_experimental module installed successfully!

# %%
from langchain.utilities import SQLDatabase
from langchain_experimental.sql import SQLDatabaseChain

# %%
import google.generativeai as genai
import os
os.environ['GOOGLE_API_KEY'] = "AIzaSyD4EKdGbVxYnB9Ua5GqqTxzQC-ETohzBIA"
genai.configure(api_key = os.environ['GOOGLE_API_KEY'])

# %%
from IPython.display import Markdown

model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("List 5 planets each with an interesting fact")

Markdown(response.text)
# Out:
# **1. Mercury:**
# - Despite being closest to the Sun, Mercury has one of the coldest surfaces in the Solar System due to its lack of an atmosphere.
#
# **2. Venus:**
# - Venus has the hottest surface of any planet in the Solar System, reaching temperatures of up to 864°F (462°C) due to a runaway greenhouse effect.
#
# **3. Earth:**
# - Earth is the only known planet in the universe with liquid water on its surface, which is essential for life.
#
# **4. Mars:**
# - Mars is often referred to as the "Red Planet" because of its iron oxide-rich soil, giving it a reddish hue.
#
# **5. Jupiter:**
# - Jupiter is the largest planet in the Solar System, with a mass 2.5 times greater than all the other planets combined. It also has a distinctive Great Red Spot, a giant storm that has been raging for centuries.

# %%
response = model.generate_content("what are top 5 frequently used emojis?")
Markdown(response.text)
# Out:
# 1. 😂 Face with Tears of Joy
# 2. ❤️ Red Heart
# 3. 👍 Thumbs Up
# 4. 🤔 Thinking Face
# 5. 🔥 Fire

# %%
response = model.generate_content("types of machine learning models ")

response.text
# Out:
# '**Supervised Learning**\n\n* **Regression Models:** Predict a continuous target variable based on input features (e.g., Linear Regression, Polynomial Regression, Decision Tree Regression)\n* **Classification Models:** Predict a categorical target variable based on input features (e.g., Logistic Regression, SVM, Decision Tree Classification)\n\n**Unsupervised Learning**\n\n* **Clustering Models:** Group similar data points together without using labeled data (e.g., K-Means, Hierarchical Clustering, DBSCAN)\n* **Dimensionality Reduction Models:** Reduce the number of features in a dataset while preserving key information (e.g., PCA, LDA, t-SNE)\n\n**Semi-Supervised Learning**\n\n* **Graph Models:** Utilize both labeled and unlabeled data to make predictions (e.g., Label Propagation, Graph Convolutional Networks)\n* **Manifold Learning:** Assumes data lies on a low-dimensional subspace in high-dimensional space (e.g., Locally Linear Embedding, ISOMAP)\n\n**Reinforcement Learning**\n\n*
# ...

# %%
response_1 = model.generate_content("types of machine learning models in tabbular format")

Markdown(response_1.text)
# Out:
# | Model Type | Description |
# |---|---|
# | **Supervised learning** | Models that learn from labeled data to predict or classify new data. |
# | **Unsupervised learning** | Models that learn from unlabeled data to find patterns or structures. |
# | **Semi-supervised learning** | Models that learn from both labeled and unlabeled data. |
# | **Reinforcement learning** | Models that learn by interacting with their environment and receiving rewards or punishments. |
# | **Generative models** | Models that can generate new data from scratch. |
# | **Discriminative models** | Models that can distinguish between different classes of data. |
# | **Linear models** | Models that use a linear combination of features to make predictions. |
# | **Nonlinear models** | Models that use more complex functions to make predictions. |
# | **Tree-based models** | Models that use decision trees to make predictions. |
# ...

# %%
import PIL.Image


image = PIL.Image.open(r'C:\Users\risha\Desktop\Data Science Project\cat.jpg')
vision_model = genai.GenerativeModel('gemini-1.5-flash')
response = vision_model.generate_content(["Write a 100 words story from the Picture",image])


Markdown(response.text)
# Out:
# The kitten lay on its side, its blue eyes gazing intently at something off-camera. A white stripe ran down its nose, contrasting with its grey and brown fur. The soft green carpet beneath it seemed to cushion the tiny feline's weight. The air was silent, save for the kitten's gentle breathing.  It was a moment of quiet contemplation, a reminder of the simple beauty found in nature's creatures.

# %%
# model = genai.GenerativeModel('gemini-1.0-pro-latest')
response = model.generate_content("The opposite of hot is")
print(response.text)
# Out:
# Cold

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
# %%time
response = model.generate_content("What is the meaning of life?")
# Out:
# CPU times: total: 0 ns
# Wall time: 7.57 s

# %%
# response = model.generate_content("What is the meaning of life?")
Markdown(response.text)
# Out:
# The meaning of life is a deeply personal question that has been contemplated by philosophers, theologians, and individuals throughout history. There is no universal answer that can satisfy everyone, as the meaning of life is often subjective and can vary depending on one's beliefs, values, and experiences.
#
# Some people believe that the meaning of life is to find happiness and fulfillment, while others believe that it is to contribute to the greater good of society or to achieve spiritual enlightenment. Some believe that life has no inherent meaning and that it is up to each individual to create their own meaning.
#
# Ultimately, the meaning of life is something that each person must decide for themselves. There is no right or wrong answer, and the journey to finding meaning can be a lifelong pursuit.
#
# Here are some common ideas about the meaning of life:
#
# ...

# %%
import PIL.Image

img = PIL.Image.open(r'C:\Users\risha\Desktop\Data Science Project\fruits.webp')
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=300x300>

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
response = model.generate_content(r'C:\Users\risha\Desktop\Data Science Project\fruits.webp')
Markdown(response.text)
# Out:
# I can't access files or open images on your computer. I am a text-based AI assistant.
#
# If you want to describe the image, you can try these things:
#
# * **Tell me about the image:** For example, you could say "The image is of a bowl of fruit with apples, oranges, and grapes."
# * **Ask me a specific question about the image:** For example, "Are there more apples or oranges in the image?"
# * **Describe the image in detail:**  For example, "The image is of a bowl of fruit with three red apples, two orange oranges, and a bunch of green grapes. The apples are all shiny and round, the oranges are slightly bumpy and the grapes are small and purple."
#
# The more detail you provide, the better I can understand the image and respond to your questions.

# %%
res = model.generate_content(['Food items in pic', img])
Markdown(res.text)
# Out:
# The food items in the picture are:
#
# * Avocado
# * Cherry tomatoes
# * Eggs
# * Green onions
# * Mushrooms
# * Spinach
# * Jalapeño peppers
